# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('iris.csv')

# %%
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data['variety'].value_counts().plot(kind='bar')

# %% [markdown]
# Plot a bar when we have more than distinct values in a column.

# %%
data['variety'].value_counts().plot(kind='pie')

# %% [markdown]
# Plot a pie when we have 4 to 5 distinct values in a column.

# %%
data['variety'].value_counts().plot(kind='line')

# %% [markdown]
# Plot a line when we have many distinct values.

# %% [markdown]
# ### Indexing data using pandas

# %% [markdown]
# * Create a time series using the <strong>date_range()</strong> function from pandas

# %%
time_series = pd.date_range('8/1/2021',periods=20)

df = pd.DataFrame(np.random.randn(20,5),index=time_series,columns=['Column 1','Column 2','Column 3','Column 4','Column 5'])

# %%
df
# Out:
#             Column 1  Column 2  Column 3  Column 4  Column 5
# 2021-08-01 -1.094924  0.054049  1.250046 -0.833338 -0.546146
# 2021-08-02 -1.602880 -0.714409  0.689914 -0.373986  0.045960
# 2021-08-03 -1.449043  0.720783 -0.698289  0.748633  0.824461
# 2021-08-04 -0.729883 -0.004033 -0.881114 -0.009186  2.634539
# 2021-08-05  1.241751 -1.884866 -0.094191 -0.263404 -1.485978
# 2021-08-06 -1.311961  1.652325  0.839896 -0.292497 -1.010309
# 2021-08-07 -0.509054  1.037729 -1.017214  1.824635  0.697094
# 2021-08-08  0.119479  0.230662 -0.944651  0.468480 -0.206281
# 2021-08-09 -0.396470 -0.274193 -0.104916  0.355368  1.169007
# 2021-08-10 -1.018145  1.341515  0.401803  0.523423  0.806862
# 2021-08-11  1.075616  0.745921 -1.204543  0.869242  0.047136
# 2021-08-12  0.243450  0.046480 -1.078349 -0.378199 -0.491478
# 2021-08-13  0.107106 -1.786860  0.790377 -0.037278  1.881429
# 2021-08-14 -0.659720  1.592093 -1.423512  0.352682 -2.001783
# ...

# %%
col1 = df['Column 1']
col1[time_series[3]]
# Out:
# -0.7298825881039352

# %%
time_series
# Out:
# DatetimeIndex(['2021-08-01', '2021-08-02', '2021-08-03', '2021-08-04',
#                '2021-08-05', '2021-08-06', '2021-08-07', '2021-08-08',
#                '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12',
#                '2021-08-13', '2021-08-14', '2021-08-15', '2021-08-16',
#                '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
x = pd.DataFrame({'x':[1,2,3],'y':[3,4,5]})
x
# Out:
#    x  y
# 0  1  3
# 1  2  4
# 2  3  5

# %%
x.loc[1] = {'x':9,'y':99}
x
# Out:
#    x   y
# 0  1   3
# 1  9  99
# 2  3   5

# %% [markdown]
# <strong>loc</strong> attribute access a group of rows or columns by labels in the given dataframe.

# %% [markdown]
# ### Slicing

# %% [markdown]
# It is a features that enables accessing sequences

# %%
df.iloc[:5,0:2]
# Out:
#             Column 1  Column 2
# 2021-08-01 -1.094924  0.054049
# 2021-08-02 -1.602880 -0.714409
# 2021-08-03 -1.449043  0.720783
# 2021-08-04 -0.729883 -0.004033
# 2021-08-05  1.241751 -1.884866

# %% [markdown]
# <strong>iloc</strong> attribute access a group of rows or columns by index location

# %% [markdown]
# ### Filtering

# %%
df[df['Column 3'] < 0]
# Out:
#             Column 1  Column 2  Column 3  Column 4  Column 5
# 2021-08-03 -1.449043  0.720783 -0.698289  0.748633  0.824461
# 2021-08-04 -0.729883 -0.004033 -0.881114 -0.009186  2.634539
# 2021-08-05  1.241751 -1.884866 -0.094191 -0.263404 -1.485978
# 2021-08-07 -0.509054  1.037729 -1.017214  1.824635  0.697094
# 2021-08-08  0.119479  0.230662 -0.944651  0.468480 -0.206281
# 2021-08-09 -0.396470 -0.274193 -0.104916  0.355368  1.169007
# 2021-08-11  1.075616  0.745921 -1.204543  0.869242  0.047136
# 2021-08-12  0.243450  0.046480 -1.078349 -0.378199 -0.491478
# 2021-08-14 -0.659720  1.592093 -1.423512  0.352682 -2.001783
# 2021-08-16  2.232674  0.408859 -1.086068 -0.104778  1.289820
# 2021-08-18 -1.779417 -0.082775 -0.313194 -0.811052  1.007655
# 2021-08-19 -1.614254  0.093370 -0.153693  0.445853 -0.984996

# %% [markdown]
# # Merging DataFrames

# %%
data1=pd.read_csv('market_fact.csv')
data2=pd.read_csv('orders_dimen.csv')

# %%
data1.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data2.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
cust_order = pd.merge(data1,data2,on='Ord_id')

# %%
cust_order.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 4  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin  Order_ID  Order_Date  \
# 0   -30.51           3.60                 0.56     36262  27-07-2010
# 1  1148.90           2.50                 0.59     36262  27-07-2010
# 2   -47.64           6.15                 0.37     36262  27-07-2010
# 3     4.56           0.93                 0.54     20513  07-07-2009
# 4   729.34          14.30                 0.37     39682  09-11-2010
#
#   Order_Priority
# 0  NOT SPECIFIED
# 1  NOT SPECIFIED
# 2  NOT SPECIFIED
# ...

# %% [markdown]
# <strong>NB:</strong> We can specify the way we want to join the two dataframes with the <strong>how</strong> parameter in the <strong>pd.merge()</strong> function.
#
# We have 4 ways to join two tables:
# <ul>
#     <li><strong>Inner join: </strong>it combines two dataframes based on common key and return a new dataframe that contains only rows that have a matching values in both original dataframes.</li>
#     <li><strong>outer join: </strong>it returns all those records which either have a match in the left or in the right dataframe.</li>
#     <li><strong>Left join: </strong>it returns a dataframe containing all rows of the left dataframe.All the non-matching rows of the left dataframe contain <strong>NaN</strong> for the columns in the right dataframe.</li>
#     <li><strong>Right join: </strong> it returns a dataframe containing all rows of the right dataframe.All the non-matching rows of the right dataframe contain <strong>NaN</strong> for the columns in the left dataframe</li>
# </ul>

# %%
cust_order = pd.merge(data1,data2,on='Ord_id',how='inner')
cust_order
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 2     Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 3     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 4     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8395  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8396  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8397  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Order_ID  \
# 0                 23   -30.51           3.60                 0.56     36262
# ...

# %% [markdown]
# # Concatenation

# %%
# dataframes having the same columns
df1 = pd.DataFrame({'Name': ['Arijit', 'Neeraj', 'Sakshi', 'Muskan'],
                    'Age': [34, 30, 22, 33],
                    'Gender': ['M', 'M', 'F', 'M']}
                  )

df2 = pd.DataFrame({'Name': ['Kartik', 'Veer', 'Preeti'],
                    'Age': [31, 22, 19],
                    'Gender': ['M', 'M', 'F']}
                  )

# %%
df1
# Out:
#      Name  Age Gender
# 0  Arijit   34      M
# 1  Neeraj   30      M
# 2  Sakshi   22      F
# 3  Muskan   33      M

# %%
df2
# Out:
#      Name  Age Gender
# 0  Kartik   31      M
# 1    Veer   22      M
# 2  Preeti   19      F

# %%
df = pd.concat([df1, df2], axis = 0)
df= df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#      Name  Age Gender
# 0  Arijit   34      M
# 1  Neeraj   30      M
# 2  Sakshi   22      F
# 3  Muskan   33      M
# 4  Kartik   31      M
# 5    Veer   22      M
# 6  Preeti   19      F

# %%
df = df1.append(df2)
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#      Name  Age Gender
# 0  Arijit   34      M
# 1  Neeraj   30      M
# 2  Sakshi   22      F
# 3  Muskan   33      M
# 4  Kartik   31      M
# 5    Veer   22      M
# 6  Preeti   19      F

# %%
df1 = pd.DataFrame({'Name': ['Arijit', 'Neeraj', 'Sakshi', 'Muskan'],
                    'Age': ['34', '30', '22', '33'],
                    'Gender': ['M', 'M', 'F', 'M']}
                  )
df2 = pd.DataFrame({'School': ['KendraVidyalay', 'Delhi Public', 'Carmel Convent', 'St. Paul'],
                    'Graduation Marks': ['84', '89', '76', '91']})

# %%
df1
# Out:
#      Name Age Gender
# 0  Arijit  34      M
# 1  Neeraj  30      M
# 2  Sakshi  22      F
# 3  Muskan  33      M

# %%
df2
# Out:
#            School Graduation Marks
# 0  KendraVidyalay               84
# 1    Delhi Public               89
# 2  Carmel Convent               76
# 3        St. Paul               91

# %%
df = pd.concat([df1,df2], axis = 1)
df
# Out:
#      Name Age Gender          School Graduation Marks
# 0  Arijit  34      M  KendraVidyalay               84
# 1  Neeraj  30      M    Delhi Public               89
# 2  Sakshi  22      F  Carmel Convent               76
# 3  Muskan  33      M        St. Paul               91

# %% [markdown]
# #  Lambda, Map, and Apply Functions

# %%
data=pd.read_csv('employees.csv')

# %%
data.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
# lets define a function to divide the Daily Rate by 100
def function(x):
    return x/10

data['SALARY'] = data['SALARY'].map(function)
data['SALARY']
# Out:
# 0      260.0
# 1      260.0
# 2      440.0
# 3     1300.0
# 4      600.0
# 5      650.0
# 6     1000.0
# 7     1200.8
# 8      830.0
# 9     2400.0
# 10    1700.0
# 11    1700.0
# 12     900.0
# 13     600.0
# 14     480.0
# 15     480.0
# 16     420.0
# 17    1200.8
# 18     900.0
# 19     820.0
# 20     770.0
# 21     780.0
# 22     690.0
# 23    1100.0
# 24     310.0
# 25     290.0
# 26     280.0
# 27     260.0
# 28     250.0
# 29     800.0
# 30     820.0
# 31     790.0
# 32     650.0
# 33     580.0
# 34     320.0
# 35     270.0
# 36     240.0
# 37     220.0
# 38     330.0
# 39     280.0
# 40     250.0
# 41     210.0
# 42     330.0
# 43     290.0
# 44     240.0
# 45     220.0
# 46     360.0
# 47     320.0
# 48     270.0
# 49     250.0
# Name: SALARY, dtype: float64

# %% [markdown]
# <strong>NB: map()</strong> function can be used only with series not dataframe.

# %%
data[['SALARY', 'DEPARTMENT_ID']].map(function)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5ec75db1bdfc> in <module>
# ----> 1 data[['SALARY', 'DEPARTMENT_ID']].map(function)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %% [markdown]
# ## Apply function

# %% [markdown]
# <strong>NB: apply()</strong> function is can alternative for <strong>map()</strong> function. It can be used with dataframe.

# %%
data[['SALARY', 'DEPARTMENT_ID']].apply(function)

# %% [markdown]
# ## Lambda function

# %%
data['SALARY'] = data['SALARY'].apply(lambda x: x/10)
print(data['SALARY'])
